# %%
# %run keyword_search.ipynb

# %% [markdown]
# # ER Abortion Episodes

# %%
er_df = pd.read_csv('./data/transcripts/er_transcripts.csv', index_col=0)

er_df = clean_transcripts(er_df)

# %%
er_df.to_csv("data\cleaned_transcripts\er_transcripts_cleaned.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\1694535126.py:1: SyntaxWarning: invalid escape sequence '\c'
#   er_df.to_csv("data\cleaned_transcripts\er_transcripts_cleaned.csv")

# %%
abortion_keys = ['abortion', 'abort', 'abortifacient']

er_abortion = get_keywords(er_df, abortion_keys)

er_abortion = er_abortion.drop([83, 111, 215])
# Out:
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\2477543652.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['query'] = True

# %% [markdown]
# # Good Doctor Abortion Episodes

# %%
gd_df = pd.read_csv('./data/transcripts/good_doctor_transcripts.csv', index_col=0)

gd_df = clean_transcripts(gd_df)

# %%
gd_df.to_csv("data\cleaned_transcripts\good_doctor_transcripts_cleaned.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\309956702.py:1: SyntaxWarning: invalid escape sequence '\c'
#   gd_df.to_csv("data\cleaned_transcripts\good_doctor_transcripts_cleaned.csv")

# %%
gd_abortion = get_keywords(gd_df, abortion_keys)
# Out:
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\2477543652.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['query'] = True

# %%
gd_abortion = gd_abortion.drop([9, 17, 33, 34, 73, 76, 82, 96, 117])

# %%
gd_abortion[['show_id', 'season', 'episode', 'excerpts']]
# Out:
#      show_id  season  episode  \
# 59   6470478       4        4
# 61   6470478       4        6
# 109  6470478       6       15
# 114  6470478       6       20
#
# ...

# %% [markdown]
# # Greys Abortion Episodes

# %%
g_df = pd.read_csv('./data/transcripts/greys_transcripts.csv', index_col=0)

g_df = clean_transcripts(g_df)

# %%
g_df.to_csv("data\cleaned_transcripts\greys_transcripts_cleaned.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\3885586449.py:1: SyntaxWarning: invalid escape sequence '\c'
#   g_df.to_csv("data\cleaned_transcripts\greys_transcripts_cleaned.csv")

# %%
g_abortion = get_keywords(g_df, abortion_keys)

g_abortion[['show_id', 'season', 'episode', 'excerpts']]
# Out:
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\2477543652.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['query'] = True
#      show_id  season  episode  \
# 6     413573       1        7
# 53    413573       3       18
# 72    413573       4       13
# 110   413573       6       10
# 145   413573       7       22
# 146   413573       8        1
# 160   413573       8       15
# 164   413573       8       19
# 227   413573      11       10
# 313   413573      14       24
# 332   413573      15       19
# 345   413573      16        7
# 399   413573      19        3
# 401   413573      19        5
# 404   413573      19        8
# 407   413573      19       11
# 408   413573      19       12
# 412   413573      19       16
#
# ...

# %%
g_abortion = g_abortion.drop([53, 313])

g_abortion[['show_id', 'season', 'episode', 'excerpts']]
# Out:
#      show_id  season  episode  \
# 6     413573       1        7
# 72    413573       4       13
# 110   413573       6       10
# 145   413573       7       22
# 146   413573       8        1
# 160   413573       8       15
# 164   413573       8       19
# 227   413573      11       10
# 332   413573      15       19
# 345   413573      16        7
# 399   413573      19        3
# 401   413573      19        5
# 404   413573      19        8
# 407   413573      19       11
# 408   413573      19       12
# 412   413573      19       16
#
# ...

# %% [markdown]
# # House Abortion Episodes

# %%
h_df = pd.read_csv('./data/transcripts/house_transcripts.csv', index_col=0)

h_df = clean_transcripts(h_df)

# %%
h_df.to_csv("data\cleaned_transcripts\house_transcripts_cleaned.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\863777908.py:1: SyntaxWarning: invalid escape sequence '\c'
#   h_df.to_csv("data\cleaned_transcripts\house_transcripts_cleaned.csv")

# %%
h_abortion = get_keywords(h_df, abortion_keys)

h_abortion[['show_id', 'season', 'episode', 'excerpts']]
# Out:
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\2477543652.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['query'] = True
#      show_id  season  episode  \
# 4     412142       1        5
# 11    412142       1       12
# 18    412142       1       19
# 57    412142       3       12
# 62    412142       3       17
# 70    412142       4        1
# 79    412142       4       10
# 170   412142       8       16
#
# ...

# %% [markdown]
# # Scrubs Abortion Episodes

# %%
s_df = pd.read_csv('./data/transcripts/scrubs_transcripts.csv', index_col=0)

s_df = clean_transcripts(s_df)

# %%
s_df.to_csv("data\cleaned_transcripts\scrubs_transcripts_cleaned.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\333691596.py:1: SyntaxWarning: invalid escape sequence '\c'
#   s_df.to_csv("data\cleaned_transcripts\scrubs_transcripts_cleaned.csv")

# %%
s_abortion = get_keywords(s_df, abortion_keys)

s_abortion[['show_id', 'season', 'episode', 'excerpts']]
# Out:
# C:\Users\joyli\AppData\Local\Temp\ipykernel_33536\2477543652.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['query'] = True
#      show_id  season  episode  \
# 73    285403       4        6
# 108   285403       5       16
# 118   285403       6        2
# 126   285403       6       10
#
# ...

# %%
s_abortion = s_abortion.drop([73])

s_abortion[['show_id', 'season', 'episode', 'excerpts']]
# Out:
#      show_id  season  episode  \
# 108   285403       5       16
# 118   285403       6        2
# 126   285403       6       10
#
# ...

# %% [markdown]
# # Combined DF

# %%
all_abortion = pd.concat([er_abortion, gd_abortion, g_abortion, h_abortion, s_abortion])

# %%
all_abortion.to_csv("data/cleaned_transcripts/abortion_episodes.csv")

# %%
episodes_flagged = update_all_eps(all_abortion)
# Out:
# C:\Users\joyli\AppData\Local\Temp\ipykernel_19784\3200578415.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   all_episodes.fillna(False, inplace=True)

# %%
episodes_flagged[episodes_flagged['abortion'] == True]
# Out:
#                                                 title  season  episode  \
# 6                            The Self-Destruct Button       1        7
# 73                                  Piece of My Heart       4       13
# 111                                          Holidaze       6       10
# 147                               Unaccompanied Minor       7       22
# 148                                      Free Falling       8        1
# 162                          Have You Seen Me Lately?       8       15
# 166                                    Support System       8       19
# 229                     The Bed's Too Big Without You      11       10
# 335                            Silent All These Years      15       19
# 348                                 Papa Don't Preach      16        7
# 402                              Let's Talk About Sex      19        3
# 404                          When I Get to the Border      19        5
# ...

# %%
episodes_flagged.to_csv("data\episodes.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\joyli\AppData\Local\Temp\ipykernel_19784\4044593475.py:1: SyntaxWarning: invalid escape sequence '\e'
#   episodes_flagged.to_csv("data\episodes.csv")
